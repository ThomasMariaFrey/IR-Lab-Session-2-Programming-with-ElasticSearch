# %% [markdown]
# Make Sure to run Notebook 1 before running Notebook 3

# %%
# !pwd
import os

# Set your own working directory here.
os.chdir(
    "/Users/thomasmariafrey/Desktop/University/IRRS-MDS Information Retrieval and Recommender Systems/Lab/Lab Work/lab2")

print(os.getcwd())
# Out:
# /Users/thomasmariafrey/Desktop/University/IRRS-MDS Information Retrieval and Recommender Systems/Lab/Lab Work/lab2
# /Users/thomasmariafrey/Desktop/University/IRRS-MDS Information Retrieval and Recommender Systems/Lab/Lab Work/lab2

# %% [markdown]
# Did not get the docs example from the lecture to work with elasic search. But the results appear to be correct when testing them with

# %%
# !python3 TFIDFViewer.py --index novels --files novels/DarwinOriginofSpecies.txt novels/DarwinOriginofSpecies.txt  --print

#Similarity of a document to itself has to be one
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/elasticsearch/connection/base.py:208: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.13/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# TFIDF FILE novels/DarwinOriginofSpecies.txt
# a, 0.0
# abdomen, 0.0036121875351138606
# aberrant, 0.01755712071503604
# aberration, 0.0028426802210471756
# abhorrent, 0.0012040625117046202
# abide, 1.5451467394724773e-05
# ability, 0.0002772118913523914
# abjectly, 0.001407659950681828
# able, 0.0022059704300774288
# ably, 0.0036121875351138606
# abnormal, 0.010423160810506309
# abnormally, 0.0010596078298600522
# abodes, 0.0012040625117046202
# aboriginal, 0.023311372256921148
# aboriginally, 0.010534272429021623
# aborigines, 0.0010596078298600522
# ...
